# %% [markdown]
# # Today we will be learning how to use tkinter and how to play around with it.
# #### our main objective is to make that video downlaoder, and for doing that, i need to learn the following things.
#  1. borderless buttons - easy to learn, are the aesthetics and can be done at the end
#  2. scrolling things inside a thing inside the main window
#  3. drop down menus
#  4. File selection menu that does the thing with the path
#  5. Change the things in the color and all
#  6. use an image in the window
#  7. Go from one window to another window and then what to do with the previous window
#  8. using funcions associated with buttons and stuff, and then aligning the windows.

# %%
import tkinter as tk

# %%
# Some constants
HEIGHT = 500
WIDTH = 600

# %% [markdown]
# 1. so first you have to create an object of the tk class, using the Tk() constructor
# 2. the convention is to call that object root, and then we close the object as in the loop of that thing
# 3. then you have to close that loop by using the root.mainloop() function, and i have no idea how that syntax works in python

# %%
# Starting the loop
root = tk.Tk()

# Creating the Canvas
canvas = tk.Canvas(root, height = HEIGHT, width = WIDTH)
canvas.pack()


# Creating the Frame
frame = tk.Frame(root, bg = 'blue')

frame.place(relwidth = 1, relheight = 1) # this is going to fill the entire screen

# relwidth and relwidth is relative tot he width, and obviously, coz it's the child of root, it's going to be relative to root
frame.place(relwidth = 0.5, relheight = 0.5) # this is going to fill half the root

# now if you want to offset this thing from teh screen somewhere, then you use the rely and the relx functions
# this is also relative as in you can just resize it.
frame.place(rely = 0.1, relx = 0.1, relwidth = 0.8, relheight = 0.8) # this is going to fill half the root

# Creating the button
button = tk.Button(frame, text="Text button", bg = 'gray', fg = 'red')
button.pack(side = 'left')

# creatign the label
label = tk.Label(frame, bg = 'green', text = 'This is some random text that i am putting here jsut to check if you can see loigs')
label.pack(side = 'left') # this is going to happen relative to the frame

entry = tk.Entry(frame, bg = 'green')
entry.pack(side = 'right') # also going to be relative to the frame thing

label2 = tk.Label(frame, bg = 'green', text = 'Thhahas')
label2.pack(side = 'bottom') # here i want to use grid view of packing and it does't work coz others aren't pack

root.mainloop()

# %% [markdown]
# ### Now doing the same thing but then using grid instead of pack
#
# this is going to print the things in a diagonal order according to the code, you have to just mess with the rows and hte columns
#
# But there isn't anything particular.
#
# You still have to make sure that hte thing you are actually doing isn't going to like be more than your height and width that you gave in the starting

# %%
# Starting the loop
root = tk.Tk()

# Creating the Canvas
canvas = tk.Canvas(root, height = HEIGHT, width = WIDTH)
canvas.pack()


# Creating the Frame
frame = tk.Frame(root, bg = 'blue')

frame.place(relwidth = 1, relheight = 1) # this is going to fill the entire screen

# relwidth and relwidth is relative tot he width, and obviously, coz it's the child of root, it's going to be relative to root
frame.place(relwidth = 0.5, relheight = 0.5) # this is going to fill half the root

# now if you want to offset this thing from teh screen somewhere, then you use the rely and the relx functions
# this is also relative as in you can just resize it.
frame.place(rely = 0.1, relx = 0.1, relwidth = 0.8, relheight = 0.8) # this is going to fill half the root

# Creating the button
button = tk.Button(frame, text="Text button", bg = '#80c1ff', fg = 'red')
button.grid(row = 0, column = 0)

# creatign the label
label = tk.Label(frame, bg = 'green', text = 'This is some random text that i am putting here jsut to check if you can see loigs')
label.grid(row = 1, column = 1) # this is going to happen relative to the frame

entry = tk.Entry(frame, bg = 'green')
entry.grid(row = 2, column = 2) # also going to be relative to the frame thing

label2 = tk.Label(frame, bg = 'green', text = 'Thhahas')
label2.grid(row = 3, column = 3) # here i want to use grid view of packing and it does't work coz others aren't pack

root.mainloop()

# %% [markdown]
# ### now we will be doing the same thing again, but using place

# %%
# Starting the loop
root = tk.Tk()

# Creating the Canvas
canvas = tk.Canvas(root, height = HEIGHT, width = WIDTH)
canvas.pack()

image1 = tk.PhotoImage(file="Parrot.png")
image1label = tk.Label(canvas, image = image1)
image1label.place(relwidth = 1, relheight = 1)
# Creating the Frame
frame = tk.Frame(root, bg = '#80c1ff')

frame.place(relwidth = 1, relheight = 1) # this is going to fill the entire screen

# relwidth and relwidth is relative tot he width, and obviously, coz it's the child of root, it's going to be relative to root
frame.place(relwidth = 0.5, relheight = 0.5) # this is going to fill half the root

# now if you want to offset this thing from teh screen somewhere, then you use the rely and the relx functions
# this is also relative as in you can just resize it.
frame.place(rely = 0.1, relx = 0.1, relwidth = 0.8, relheight = 0.8) # this is going to fill half the root



# Creating the button
button = tk.Button(frame, text="Text button", bg = 'blue', fg = 'red')
button.place(rely = 0, relx = 0, relwidth = 0.25, relheight = 0.2)

# creatign the label
label = tk.Label(frame, bg = 'green', text = 'This is some')
label.place(rely = 0, relx = 0.26, relwidth = 0.25, relheight = 0.2) # this is going to happen relative to the frame

entry = tk.Entry(frame, bg = 'red')
entry.place(rely = 0, relx = 0.52, relwidth = 0.2, relheight = 0.2) # also going to be relative to the frame thing

root.mainloop()

# the numbers are pretty important here. but then because they are relative, you don't need to worry, everything happens in terms
# or percentage so you don't even have to think about where exactly you are going to be putting things, so that makes putting
# things much easier than pygame. so using the place function, you can basically put anything anywhere and that should be it about
# the geometry of putting things in tkinter

# %% [markdown]
# ## Looking at using stuff from buttons and things like that
# customising the buttons and all is like stuff that we can do just by watchign something, right now, that is not the prority and so we should next learn about how to use the things.

# %% [markdown]
# ### Here we will see how to use a scrollbar in tkinter
#
# It has basically all the things that we need to display the multiple playlists

# %%
from tkinter import *

root = Tk()
scrollbar = Scrollbar(root)
scrollbar.pack( side = RIGHT, fill = Y )

mylist = Listbox(root, yscrollcommand = scrollbar.set )
for line in range(100):
   mylist.insert(END, "This is line number " + str(line))

mylist.pack( side = LEFT, fill = BOTH )
scrollbar.config( command = mylist.yview )
mainloop()

# %% [markdown]
# ## This is how to open that file explorer thing to get the file path for the downlaods

# %%
from tkinter import Tk     # from tkinter import Tk for Python 3.x
from tkinter.filedialog import askopenfilename

Tk().withdraw() # we don't want a full GUI, so keep the root window from appearing
filename = askopenfilename() # show an "Open" dialog box and return the path to the selected file
print(filename)

# %% [markdown]
# ### These are the different types of buttons default in tkinter
#
# groove is the best one tho

# %%
from tkinter import *
import tkinter

top = tkinter.Tk()

B1 = tkinter.Button(top, text ="FLAT", relief=FLAT )
B2 = tkinter.Button(top, text ="RAISED", relief=RAISED )
B3 = tkinter.Button(top, text ="SUNKEN", relief=SUNKEN )
B4 = tkinter.Button(top, text ="GROOVE", relief=GROOVE )
B5 = tkinter.Button(top, text ="RIDGE", relief=RIDGE )

B1.pack()
B2.pack()
B3.pack()
B4.pack()
B5.pack()
top.mainloop()

# %% [markdown]
# ### This is a different way to display buttons - Color change

# %%
from tkinter import *
widget = Button(text='Spam', padx=10, pady=10)
widget.pack(padx=20, pady=20)
widget.config(cursor='gumby')
widget.config(bd=8, relief=RAISED)
widget.config(bg='dark green', fg='white')
widget.config(font=('helvetica', 20, 'underline italic'))
mainloop()

# %%
from tkinter import *

root = Tk()
 
myContainer1 = Frame(root)
myContainer1.pack()

button1 = Button(myContainer1)      
button1["text"]= "Hello, World!"    
button1["background"] = "green"     
button1.pack()                      

root.mainloop()

# %% [markdown]
# ### This is how you use a function with a button

# %%
from tkinter import *

root = Tk()

def callback():
    print ("called the callback!")
# create a toolbar
toolbar = Frame(root)

b = Button(toolbar, text="new", width=16, command=callback)
b.pack(side=LEFT, padx=2, pady=2)

b = Button(toolbar, text="open", width=6, command=callback)
b.pack(side=LEFT, padx=2, pady=2)

toolbar.pack(side=TOP, fill=X)

mainloop()

# %% [markdown]
# ### This is how to use drop down menus

# %%
from tkinter import *
import tkinter as ttk

root = Tk()
root.title("Tk dropdown example")

# Add a grid
mainframe = Frame(root)
mainframe.grid(column=0,row=0, sticky=(N,W,E,S) )
mainframe.columnconfigure(0, weight = 1)
mainframe.rowconfigure(0, weight = 1)
mainframe.pack(pady = 100, padx = 100)

# Create a Tkinter variable
tkvar = StringVar(root)

# Dictionary with options
choices = { 'Pizza','Lasagne','Fries','Fish','Potatoe'}
tkvar.set('Pizza') # set the default option

popupMenu = OptionMenu(mainframe, tkvar, *choices)
Label(mainframe, text="Choose a dish").grid(row = 1, column = 1)
popupMenu.grid(row = 2, column =1)

# on change dropdown value
def change_dropdown(*args):
    print( tkvar.get() )

# link function to change dropdown
tkvar.trace('w', change_dropdown)

root.mainloop()

# %% [markdown]
# ### This is hwo to import an image in tkinter

# %%
import tkinter as tk
root = tk.Tk()
root.title('background image')


image1 = tk.PhotoImage(file="Parrot.png")
image1label = tk.Label(root, image = image1)
image1label.place(relwidth = 1, relheight = 1)
root.mainloop()

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\littl\Desktop\Programs\Python\Learning Python Libraries\Tkinter

# %%
from tkinter import *

root = Tk()
var = StringVar()
var.set('hello')

l = Label(root, textvariable = var)
l.pack()

t = Entry(root, textvariable = var)
t.pack()

root.mainloop() # the window is now displayed

# %% [markdown]
# ## this is how you will show an image as a button
#
#
# you still need to resize the button and all that

# %%
from tkinter import *
root = Tk()
root.title('rounded image to buttons')
root.geometry("1280x720")

def thing():
    mylabel.config(text = "You clicked the button...")
    

login_btn = PhotoImage(
    file = 'C:/Users/littl/Desktop/Programs/Python/Learning Python Libraries/Tkinter/download.png')
image_label = Label(image = login_btn)

my_button = Button(root, image = login_btn, command = thing, borderwidth = 0)
my_button.pack(pady = 20)

mylabel = Label(root, text = '')
mylabel.pack(pady = 30)
mainloop()

# %% [markdown]
# ## How to run a progress bar in tkinter

# %%
# importing tkinter module 
from tkinter import *
from tkinter.ttk import *
  
# creating tkinter window 
root = Tk() 
  
# Progress bar widget 
progress = Progressbar(root, orient = HORIZONTAL, 
              length = 100, mode = 'determinate') 
  
# Function responsible for the updation 
# of the progress bar value 
def bar(): 
    import time 
    progress['value'] = 20
    root.update_idletasks() 
    time.sleep(1) 
  
    progress['value'] = 40
    root.update_idletasks() 
    time.sleep(1) 
  
    progress['value'] = 50
    root.update_idletasks() 
    time.sleep(1) 
  
    progress['value'] = 60
    root.update_idletasks() 
    time.sleep(1) 
  
    progress['value'] = 80
    root.update_idletasks() 
    time.sleep(1) 
    progress['value'] = 100
  
progress.pack(pady = 10) 
  
# This button will initialize 
# the progress bar 
Button(root, text = 'Start', command = bar).pack(pady = 10) 
  
# infinite loop 
mainloop()

# %%
import tkinter as tk
from tkinter import ttk


class SampleApp(tk.Tk):

    def __init__(self, *args, **kwargs):
        tk.Tk.__init__(self, *args, **kwargs)
        self.button = ttk.Button(text="start", command=self.start)
        self.button.pack()
        self.progress = ttk.Progressbar(self, orient="horizontal",
                                        length=200, mode="determinate")
        self.progress.pack()

        self.bytes = 0
        self.maxbytes = 0

    def start(self):
        self.progress["value"] = 0
        self.maxbytes = 50000
        self.progress["maximum"] = 50000
        self.read_bytes()

    def read_bytes(self):
        '''simulate reading 500 bytes; update progress bar'''
        self.bytes += 500
        self.progress["value"] = self.bytes
        if self.bytes < self.maxbytes:
            # read more bytes after 100 ms
            self.after(100, self.read_bytes)

app = SampleApp()
app.mainloop()

# %%
import tkinter as tk
from tkinter import ttk


class SampleApp(tk.Tk):

    def __init__(self, *args, **kwargs):
        tk.Tk.__init__(self, *args, **kwargs)
        self.button = ttk.Button(text="start", command=self.start)
        self.button.pack()
        self.progress = ttk.Progressbar(self, orient="horizontal",
                                        length=200, mode="determinate")
        self.progress.pack()

        self.bytes = 0
        self.maxbytes = 0

    def on_progress_dothis( stream, chunk: bytes, bytes_remaining: int ) -> None:  # pylint: disable=W0613
        self.bytes = self.maxbytes - self.bytes
        percent = (100 * (self.maxbytes-bytes_remaining) ) / self.maxbytes
        print(percent)
        self.progress["value"] = self.bytes
        
    #Grabs the file path for Download
    def file_path():
        home = os.path.expanduser('~')
        download_path = os.path.join(home, 'Downloads')
        return download_path

    def start(self):
        self.progress["value"] = 0

        
        print("Your video will be saved to: {}".format(file_path()))
        yt_url = 'https://www.youtube.com/watch?v=IpN_wAlYZSs'
        print ("Accessing YouTube URL...")
        video = YouTube(yt_url, on_progress_callback = self.on_progress_dothis)
        video_type = video.streams.filter(progressive = True, file_extension = "mp4").first()
        print ("Fetching")
        self.maxbytes = video_type.filesize
        self.progress["maximum"] = self.maxbytes
        video_type.download(self.file_path())
        
    def read_bytes(self):
        '''simulate reading 500 bytes; update progress bar'''
        self.bytes += 500
        self.progress["value"] = self.bytes
        if self.bytes < self.maxbytes:
            # read more bytes after 100 ms
            self.after(100, self.read_bytes)

app = SampleApp()
app.mainloop()

# %% [markdown]
# ## these are backups

# %%
"""
pytube 9.0.6, Python 3

Creating a simple You Tube downloader with a simple progress indicator.progress indicator.

"""
# sample: https://www.youtube.com/watch?v=d3D7Y_ycSms

from pytube import YouTube
import os
from pytube.cli import on_progress

import pytube


# importing tkinter module 
from tkinter import *
from tkinter.ttk import *
  
  
# Function responsible for the updation 
# of the progress bar value
import time 






VALUE = 0









def on_progress_dothis( stream, chunk: bytes, bytes_remaining: int ) -> None:  # pylint: disable=W0613
    global Value
    filesize = stream.filesize
    bytes_received = filesize - bytes_remaining
    percent = (100*(filesize-bytes_remaining))/filesize
    VALUE = percent
    print(VALUE)
    print("{:00.0f}% downloaded".format(percent))

    
#Grabs the file path for Download
def file_path():
    home = os.path.expanduser('~')
    download_path = os.path.join(home, 'Downloads')
    return download_path

def start():
    print("Your video will be saved to: {}".format(file_path()))
    yt_url = 'https://www.youtube.com/watch?v=IpN_wAlYZSs'
    print ("Accessing YouTube URL...")
    video = YouTube(yt_url, on_progress_callback = on_progress_dothis)
    video_type = video.streams.filter(progressive = True, file_extension = "mp4").first()
    print ("Fetching")
    global file_size
    file_size = video_type.filesize
    video_type.download(file_path())







  
def ramesh():  
    # creating tkinter window 
    root = Tk() 
      
    
    def bar(): 
        progress['value'] = VALUE
        root.update_idletasks() 
        time.sleep(1) 
    # Progress bar widget 
    progress = Progressbar(root, orient = HORIZONTAL, 
              length = 100, mode = 'determinate') 
  

    progress.pack(pady = 10) 

    Button(root, text = 'download', command = lambda:[start()]).pack(pady = 10) 
  
    # infinite loop 
    mainloop()






file_size = 0
begin = start()

# %% [markdown]
# ## This is a working backup of a youtube video downloader with a working progress bar in tkinter

# %%
import tkinter as tk
from tkinter import ttk

from pytube import YouTube
import os
from pytube.cli import on_progress

import pytube

  
# Function responsible for the updation 
# of the progress bar value
import time 




class SampleApp(tk.Tk):

    def __init__(self, *args, **kwargs):
        tk.Tk.__init__(self, *args, **kwargs)
        self.button = ttk.Button(text="start", command=self.start)
        self.button.pack()
        self.progress = ttk.Progressbar(self, orient="horizontal",
                                        length=200, mode="determinate")
        self.progress.pack()

        self.bytes = 0
        self.maxbytes = 0

    def on_progress_dothis(self, stream, chunk: bytes, bytes_remaining: int ) -> None:  # pylint: disable=W0613
        self.bytes = self.maxbytes - bytes_remaining
        percent = (100 * (self.maxbytes-bytes_remaining) ) / self.maxbytes
        self.progress["value"] = self.bytes
        self.update_idletasks()
                
    #Grabs the file path for Download
    @staticmethod
    def file_path():
        home = os.path.expanduser('~')
        download_path = os.path.join(home, 'Downloads')
        return download_path

    def start(self):
        self.progress["value"] = 0

        
        print("Your video will be saved to: {}".format(self.file_path()))
        yt_url = 'https://www.youtube.com/watch?v=jgkMFBDyzE8'
        print ("Accessing YouTube URL...")
        video = YouTube(yt_url, on_progress_callback = self.on_progress_dothis)
        video_type = video.streams.filter(progressive = True, file_extension = "mp4").first()
        print ("Fetching")
        self.maxbytes = video_type.filesize
        self.progress["maximum"] = self.maxbytes
        video_type.download(self.file_path())


app = SampleApp()
app.mainloop()

# %%
def start():
    print("Your video will be saved to: {}".format(file_path()))
    #Input
    #yt_url = input("Copy and paste your YouTube URL here: ")
    #print(yt_url)
    yt_url = 'https://www.youtube.com/watch?v=IpN_wAlYZSs'
    print ("Accessing YouTube URL...")

    # Searches for the video and sets up the callback to run the progress indicator.
    try:
        video = YouTube(yt_url, on_progress_callback = on_progress_dothis)
    except:
        print("ERROR. Check your:\n  -connection\n  -url is a YouTube url\n\nTry again.")
        redo = start()

    #Get the first video type - usually the best quality.
    video_type = video.streams.filter(progressive = True, file_extension = "mp4").first()

    #Gets the title of the video
    title = video.title

    #Prepares the file for download
    print ("Fetching: {}...".format(title))
    global file_size
    file_size = video_type.filesize
    #Starts the download process
    video_type.download(file_path())

# %% [markdown]
# # AND FINALLY HERE IS THE FINAL BACKUP
#
# using this, if you provide a link to a youtuve video, then you can actually freaking download the video, while at the same time viewing the progress in a bloddy (green) progress bar
#
# this is possible coz i know a little bit about how classes and their methods work, and how to fix those tiny errors, and i also learned a bit of fancy worded shit called multithreading, and its freaking useful, i dont even know why we don't learn multithreading in the beginning, like the visual sort of arrays must have been easier with this in the background.
#
# anyway so we actually have a class that inherits the Tk() class and and is a child of that class, and into that we have obviously the init function, which starts the whole thing, and you have the downlaod button, which on press has a command function related to it.
#
# this command function is the threading bit, where we know there are two function, one is for reading the bytes on the screen, as in feeding it to the progressbar in tkinter, and the other one is obviously for downloading the youtube video. so the threading thing assigns a thread for both of these, and they run simultainously.
#
# so the downloading dude runs, and then saves the downloaded bits into the self.bytes variables, and the other funciton accesses it at the same time, and so they update and work well.

# %%
import tkinter as tk
from tkinter import ttk

from pytube import YouTube
import os
from pytube.cli import on_progress

import pytube
from threading import *
  
# Function responsible for the updation 
# of the progress bar value
import time 




class SampleApp(tk.Tk):

    def __init__(self, *args, **kwargs):
        tk.Tk.__init__(self, *args, **kwargs)
        self.button = ttk.Button(text="start", command=self.begins)
        self.button.pack()
        self.progress = ttk.Progressbar(self, orient="horizontal",
                                        length=200, mode="determinate")
        self.progress.pack()

        self.bytes = 0
        self.maxbytes = 0

    def on_progress_dothis(self, stream, chunk: bytes, bytes_remaining: int ) -> None:  # pylint: disable=W0613
        self.bytes = self.maxbytes - bytes_remaining
        percent = (100 * (self.maxbytes-bytes_remaining) ) / self.maxbytes
        self.progress["value"] = self.bytes
        self.update_idletasks()
                
    #Grabs the file path for Download
    @staticmethod
    def file_path():
        home = os.path.expanduser('~')
        download_path = os.path.join(home, 'Downloads')
        return download_path

    def begins(self):
        t1 = Thread(target = self.download)
        t2 = Thread(target = self.read_bytes)
        t1.start()
        t2.start()

    def download(self):
        self.progress["value"] = 0
        print("Your video will be saved to: {}".format(self.file_path()))
        yt_url = 'https://www.youtube.com/watch?v=IpN_wAlYZSs'
        print ("Accessing YouTube URL...")
        video = YouTube(yt_url, on_progress_callback = self.on_progress_dothis)
        video_type = video.streams.filter(progressive = True, file_extension = "mp4").first()
        print ("Fetching")
        self.maxbytes = video_type.filesize
        self.progress["maximum"] = self.maxbytes
        video_type.download(self.file_path())
    
    def read_bytes(self):
        self.progress["value"] = self.bytes
        if self.bytes < self.maxbytes:
            self.after(100, self.read_bytes)

app = SampleApp()
app.mainloop()

# %% [markdown]
# now i need to still work a lot on this project, and as simple and easy as it sounds, it isn't actually, i mean it is, but just it isn't for me, it will be eventually tho.
#
# anyway so this whole thing is going to be dropped until 20th of september, and after that we will resume and finish it, hopefully by the end of this month.
#
# so its a wrap for today and these few days, coz nothing else is going to take this long to figure out. jupyter has actually been a great great help all along, and its going to be there. for a long time. i also really have to give thonny the credits here as well, coz its the only light program, which has a very configurable interpreter settings, and it comes pre installed with python, it is also pretty portable, and it only takes like 20 mb of ram while running, which means i can run other things at the same time, for long thought out coding, i would still prefer pycharm, but thonny is pretty good, like really really good for thigns like these, you can't really debug, i mean you can like you don't need ides for things like this all the time, there still is the idle debugger and you can actually use it as well, but its fine, if you don't need to debug and all.
#
# so thonny, because of all these benefits, easily trumps notepad++ in its python capabilites, notepad++ is obviosuly the overall champion of all the things, but then thonny is a good ide for python specific shit, and opens up fast. so its going to be my default for opening .py files from now on. another advantage is that you can easily create new venvs as well, tho these are created by the default 3.7 thing, so you may have to use cmd for custom creations of venvs.
#
#
# so things left to do in this project are
# 1. i have to rearrange how my basic structure of the code is, and fix the progress bar
# 2. change the resolution, of the window and the images, and figure out what goes where
# 3. figure out the file path display system
# 4. make all the buttons into images and change the borderwidth = 0
# 5. figure out how to have multiple streams and quality in the quality drop down menu
# 6. figure out how to deal with playlists.
# 7. redesign the logo and the bg images a little bit
# 8. make the other pages i mean design them.
# 9. figure out how to download only particular videos from playlists
# 10. add the kappa video downloader kernal to jupyter, transfer all the files and stuff from there, as well as here into those jupyter files and then work on them and see how it feels to work entirely on jupyter for a project.
# 11. focus on writing shorter and cleaner code

# %%
"""
# importing the things
import tkinter as tk
from tkinter import ttk
import pytube as pt
import urllib.request
import requests
import os
from tkinter.filedialog import askopenfilename
from PIL import ImageTk, Image
from threading import *
import re


# from pytube import YouTube
# from pytube import Playlist
''' # issues to fix
# 1. Fix that file locatoinn of the image thing
2. fix resizing
3. fix the error on suddenly closing the window
'''

# defining Some constants

HEIGHT = 720
WIDTH = 1280
TYPE = 'SINGLE'
INTRO_BGIMG = "C:/Users/littl/Desktop/Programs/Python/Kappa Video Downloader/Assets/Background Images/INTRO BGIMG.png"
VIDDOWN_SINGLE_BGIMG = "C:/Users/littl/Desktop/Programs/Python/Kappa Video Downloader/Assets/Background Images/VIDDOWN SINGLE BGIMG.png"
URL = ''
FILENAME = os.getcwd()
maxbytes = 0
Bytes = 0
sth = 1
class General :
    
    # gets the id of the video from the url, this id is used to store the thumbnail of the video later on
    @staticmethod
    def get_vid_id( url ) :
        return url[ url.index( "=" ) + 1 : ]
    
    
    # Gets the video thumbnail and saves it in the correct folder
    @staticmethod
    def get_video_tnl( url, tnurl ) :
        vid_id = General.get_vid_id( url ) + '.png'
        tnl = urllib.request.urlretrieve( tnurl, os.path.join( 'Assets/Thumbnails', vid_id ) )
        return tnl
    
    # Convers the lengths of the videos from seconds to displayable and understandable formats
    @staticmethod
    def conv_len( length ) :
        print( length )
        minutes_or_hours = length // 60  # 563
        if minutes_or_hours < 60 :
            print( minutes_or_hours )
            minutes = minutes_or_hours
            seconds = length - (60 * minutes)
            if minutes < 10 :
                vid_len = '00:0' + str( minutes ) + ':' + str( seconds )
            else :
                vid_len = '00:0' + str( minutes ) + ':' + str( seconds )
            return vid_len
        else :
            print( minutes_or_hours )
            hours = minutes_or_hours // 60
            print( 'hours', hours )
            minutes = (minutes_or_hours - (60 * hours))
            our_seconds = hours * 3600 + minutes * 60
            seconds = length - our_seconds
            if minutes < 10 and seconds < 10 :
                vid_len = str( hours ) + ':0' + str( minutes ) + ':0' + str( seconds )
            elif minutes < 10 and seconds > 10 :
                vid_len = str( hours ) + ':0' + str( minutes ) + ':' + str( seconds )
            else :
                vid_len = str( hours ) + ':' + str( minutes ) + ':' + str( seconds )
            
            return vid_len

class window :
    
    # function that displays the introduction tkinter window, and has enter button that closes it. Also checks if the
    # link is a playlist or a single video, and if it is, then it changes the type from single to playlist
    # it then returns the url of the video
    @staticmethod
    def intro_win() :
        global TYPE
        
        # this gets executed just after button is pressed, it gets the url from the user, and checks if it is valid
        # if the url is valid, then it assigns the value of TYPE as single or playlist, and if not, then 'invalid'
        def proceed() :
            global TYPE, URL
            user_url = entry.get()
            r = requests.get( user_url )  # random video id
            if "Video unavailable" in r.text :
                print( 'video is invalid' )
                TYPE = 'invalid'
            else :
                if 'list=' in user_url :
                    TYPE = 'PLAYLIST'
                    print('its a playlist')
                else: TYPE = 'SINGLE'
                print( 'this shit is the url', user_url )
                URL = user_url
        
        
        # Beginning loop from here
        
        root = tk.Tk()
        BG_IMG = tk.PhotoImage( file = INTRO_BGIMG )
        
        canvas = tk.Canvas( root, height = HEIGHT, width = WIDTH )
        canvas.pack()
        
        # Placing the background image in the canvas
        BG_IMG_LABEL = tk.Label( canvas, image = BG_IMG )
        BG_IMG_LABEL.place( relwidth = 1, relheight = 1 )
        
        entry = tk.Entry( canvas, bg = 'white', font = ("Calibre", 13) )
        entry.place( rely = 0.6, relx = 0.1, relwidth = 0.8, relheight = 0.1, )
        
        proceed_btn = tk.Button( canvas, text = "Proceed", command = lambda : [ proceed(), root.destroy() ] )
        proceed_btn.place( rely = 0.8, relx = 0.4, relwidth = 0.2, relheight = 0.1 )
        
        root.mainloop()
    
    # this window shows you the thumbnail of the video along with its title and available qualities, also shows you the
    # download button and the file path selection menu. You click download and the video downloades.
    @staticmethod
    def sel_download_win_single( url, tnurl, title, length, author ) :
        
        # on change dropdown value, and link to the main menu
        def change_dropdown( *args ) :
            print( tkvar.get() )
        
        # on pressing the download button
        def download_btn() :
            global sth
            print( 'video downlaoding' )
            #window.download(url, os.getcwd())
            progress_bar['value'] = Bytes
            
        def begins( ) :
            t1 = Thread( target = download( os.getcwd() ) )
            t2 = Thread( target = download_btn() )
            t1.start()
            t2.start()

        def on2_progress_dothis( stream, chunk: bytes, bytes_remaining: int ) -> None :  # pylint: disable=W0613
            global Bytes
            Bytes = maxbytes - bytes_remaining
            percent = (100 * (maxbytes - bytes_remaining)) / maxbytes
            print( percent )
            root.update_idletasks()
    
        def open_file_explorer() :
            global FILENAME, file_path_var
            tk.Tk().withdraw()
            file_path_var = tk.filedialog.askdirectory()
            print( file_path_var )
            FILENAME = file_path_var
            return file_path_var
        
        # Starting the loop
        root = tk.Tk()
        file_path_var = tk.StringVar()
        file_path_var.set( FILENAME )
        BG_IMG = tk.PhotoImage( file = VIDDOWN_SINGLE_BGIMG )
        
        # Creating the Canvas
        canvas = tk.Canvas( root, height = HEIGHT, width = WIDTH )
        canvas.pack()
        
        # Placing the background image in the canvas
        BG_IMG_LABEL = tk.Label( canvas, image = BG_IMG )
        BG_IMG_LABEL.place( relwidth = 1, relheight = 1 )
        
        # scrapping the thumbnail from the current video and putting it in some folder
        General.get_video_tnl( url, tnurl )
        
        # displaying the thumbnail
        img = Image.open( os.path.join( 'Assets/Thumbnails', General.get_vid_id( url ) + '.png' ) )
        img = img.resize( (220, 123), Image.ANTIALIAS )
        img = ImageTk.PhotoImage( img )
        video_tnl = tk.Label( canvas, image = img )
        video_tnl.place( relwidth = 0.32, relheight = 0.27 )
        
        # displaying the title of the video
        vid_title = tk.Label( canvas, text = title, anchor = 'w', font = ("Calibre", 14), bg = 'white', wraplength = 400 )
        vid_title.place( relx = 0.35, relwidth = 0.8, relheight = 0.2 )
        
        # displaying the length of the video
        vid_len = General.conv_len( length )
        vid_length = tk.Label( canvas, text = vid_len, anchor = 'w', font = ("Calibre", 14), bg = 'white', wraplength = 400 )
        vid_length.place( rely = 0.20, relx = 0.35, relwidth = 0.3, relheight = 0.1 )
        
        
        # Creaing the drop down menu
        
        tkvar = tk.StringVar( root )
        list1 = [ 1, 2, 3, 4, 5 ]
        tkvar.set( list1[ 0 ] )  # set the default option
        popupMenu = tk.OptionMenu( canvas, tkvar, *list1 )
        quality_menu = tk.Label( canvas, text = "Choose Quality" )
        quality_menu.place( rely = 0.3, relwidth = 0.2, relheight = 0.1 )
        popupMenu.place( rely = 0.4, relwidth = 0.2, relheight = 0.1 )
        tkvar.trace( 'w', change_dropdown )
        
        
        # Displaying the download button
        down_btn = tk.Button( canvas, text = "Downlaod", command = begins, font = ("Calibre", 16) )
        down_btn.place( rely = 0.3, relx = 0.7, relwidth = 0.3, relheight = 0.2 )
        
        # displaying the file selection button
        file_selection_btn = tk.Button( canvas, text = "...", command = open_file_explorer, font = ("Calibre", 16) )
        file_selection_btn.place( rely = 0.7, relx = 0.8, relwidth = 0.05, relheight = 0.05 )
        
        # displaying the file path text box
        file_path = tk.Label( canvas, text = file_path_var )
        file_path.place( rely = 0.7, relx = 0.1, relwidth = 0.7, relheight = 0.1 )
        
        progress_bar = ttk.Progressbar(canvas, orient="horizontal",
                                        length=200, mode="determinate")
        progress_bar.place(rely = 0.8, relx = 0.1, relwidth = 0.7, relheight = 0.1)
        progress_bar['value'] = 20

        def on_progress_dothis( stream, chunk: bytes, bytes_remaining: int ) -> None :  # pylint: disable=W0613
            global Bytes
            Bytes = maxbytes - bytes_remaining
            percent = (100 * (maxbytes - bytes_remaining)) / maxbytes
            print( percent )
            progress_bar[ "value" ] = Bytes
            root.update_idletasks()

        def download( filepath ) :
            global maxbytes
            print( "Accessing YouTube URL..." )
            video = pt.YouTube( url, on_progress_callback = on_progress_dothis )
            video_type = video.streams.filter( progressive = True, file_extension = "mp4" ).first()
            print( "Fetching" )
            maxbytes = video_type.filesize
            print( maxbytes )
            video_type.download( filepath )
        
        root.mainloop()
    
    # this window shows you the thumbnail of each video in a scrollbar fashion(?) and then you download and there is checkbox
    @staticmethod
    def sel_downlaod_win_playlist() :
        pass
    

    
def main() :
    # runs the intro function first to get the url
    window.intro_win()
    
    if TYPE == 'SINGLE' :
        url1 = 'https://www.youtube.com/watch?v=D8-snVfekto&t=2162s'
        print( URL )
        yt = pt.YouTube( URL )
        


        
        window.sel_download_win_single( "https://www.youtube.com/watch?v=D8-snVfekto&t=2162s",
                                        yt.thumbnail_url, yt.title, yt.length, yt.author )
    else :
        window.sel_downlaod_win_playlist()

main()
"""

# importing the things
import tkinter as tk
from tkinter import ttk
import pytube as pt
import urllib.request
import requests
import os
from tkinter.filedialog import askopenfilename
from PIL import ImageTk, Image
import threading
import re


# from pytube import YouTube
# from pytube import Playlist
''' # issues to fix
# 1. Fix that file locatoinn of the image thing
2. fix resizing
3. fix the error on suddenly closing the window
'''

# defining Some constants

HEIGHT = 720
WIDTH = 1280
TYPE = 'SINGLE'
INTRO_BGIMG = "C:/Users/littl/Desktop/Programs/Python/Kappa Video Downloader/Assets/Background Images/INTRO BGIMG.png"
VIDDOWN_SINGLE_BGIMG = "C:/Users/littl/Desktop/Programs/Python/Kappa Video Downloader/Assets/Background Images/VIDDOWN SINGLE BGIMG.png"
DOWNLAOD_IMAGE = "C:/Users/littl/Desktop/Programs/Python/Learning Python Libraries/Tkinter/download.png"
URL = ''
FILENAME = os.getcwd()
maxbytes = 0
sth = 1
again = True

class General :
    
    # gets the id of the video from the url, this id is used to store the thumbnail of the video later on
    @staticmethod
    def get_vid_id( url ) :
        return url[ url.index( "=" ) + 1 : ]
    
    # Gets the video thumbnail and saves it in the correct folder
    @staticmethod
    def get_video_tnl( url, tnurl ) :
        vid_id = General.get_vid_id( url ) + '.png'
        tnl = urllib.request.urlretrieve( tnurl, os.path.join( 'Assets/Thumbnails', vid_id ) )
        return tnl
    
    # Convers the lengths of the videos from seconds to displayable and understandable formats
    @staticmethod
    def conv_len( length ) :
        print( length )
        minutes_or_hours = length // 60  # 563
        if minutes_or_hours < 60 :
            print( minutes_or_hours )
            minutes = minutes_or_hours
            seconds = length - (60 * minutes)
            if minutes < 10 :
                vid_len = '00:0' + str( minutes ) + ':' + str( seconds )
            else :
                vid_len = '00:0' + str( minutes ) + ':' + str( seconds )
            return vid_len
        else :
            print( minutes_or_hours )
            hours = minutes_or_hours // 60
            print( 'hours', hours )
            minutes = (minutes_or_hours - (60 * hours))
            our_seconds = hours * 3600 + minutes * 60
            seconds = length - our_seconds
            if minutes < 10 and seconds < 10 :
                vid_len = str( hours ) + ':0' + str( minutes ) + ':0' + str( seconds )
            elif minutes < 10 and seconds > 10 :
                vid_len = str( hours ) + ':0' + str( minutes ) + ':' + str( seconds )
            else :
                vid_len = str( hours ) + ':' + str( minutes ) + ':' + str( seconds )
            
            return vid_len

class window :
    
    # function that displays the introduction tkinter window, and has enter button that closes it. Also checks if the
    # link is a playlist or a single video, and if it is, then it changes the type from single to playlist
    # it then returns the url of the video
    @staticmethod
    def intro_win() :
        global TYPE
        
        # this gets executed just after button is pressed, it gets the url from the user, and checks if it is valid
        # if the url is valid, then it assigns the value of TYPE as single or playlist, and if not, then 'invalid'
        def proceed() :
            global TYPE, URL
            user_url = entry.get()
            r = requests.get( user_url )  # random video id
            if "Video unavailable" in r.text :
                print( 'video is invalid' )
                TYPE = 'invalid'
            else :
                if 'list=' in user_url :
                    TYPE = 'PLAYLIST'
                    print( 'its a playlist' )
                else :
                    TYPE = 'SINGLE'
                print( 'this shit is the url', user_url )
                URL = user_url
        
        # Beginning loop from here
        
        root = tk.Tk()
        BG_IMG = tk.PhotoImage( file = INTRO_BGIMG )
        
        canvas = tk.Canvas( root, height = HEIGHT, width = WIDTH )
        canvas.pack()
        
        # Placing the background image in the canvas
        BG_IMG_LABEL = tk.Label( canvas, image = BG_IMG )
        BG_IMG_LABEL.place( relwidth = 1, relheight = 1 )
        
        entry = tk.Entry( canvas, bg = 'white', font = ("Calibre", 13) )
        entry.place( rely = 0.80, relx = 0.24, relwidth = 0.55, relheight = 0.05, )
        
        proceed_btn = tk.Button( canvas, text = "Proceed", command = lambda : [ proceed(), root.destroy() ] )
        proceed_btn.place( rely = 0.9, relx = 0.45, relwidth = 0.1, relheight = 0.05 )
        
        root.mainloop()
    
    # this window shows you the thumbnail of the video along with its title and available qualities, also shows you the
    # download button and the file path selection menu. You click download and the video downloades.
    @staticmethod
    def sel_download_win_single( url, tnurl, title, length, author ) :
        
        global again
        
        # on change dropdown value, and link to the main menu
        def change_dropdown( *args ) :
            print( tkvar.get() )
        
        def open_file_explorer() :
            global FILENAME
            tk.Tk().withdraw()
            FILENAME = tk.filedialog.askdirectory()
            print( FILENAME )
            file_path.config( text = FILENAME )
        
        def on_progress_dothis( stream, chunk: bytes, bytes_remaining: int ) -> None :  # pylint: disable=W0613
            Bytes = maxbytes - bytes_remaining
            percent = round( (100 * (maxbytes - bytes_remaining)) / maxbytes, 2 )
            downloading = 'Downloading... ' + percent.__str__() + '%'
            progress_bar[ "value" ] = Bytes
            progress_value.config( text = downloading )
            root.update_idletasks()
            if percent == 100.0 :
                downloading = '       Done! '
                progress_value.config( text = downloading )
        
        def download() :
            global maxbytes
            print( "Accessing YouTube URL..." )
            video = pt.YouTube( url, on_progress_callback = on_progress_dothis )
            video_type = video.streams.get_by_itag( 22 )
            if video_type is None :
                video_type = video.streams.get_by_itag( 18 )
            print( "Fetching" )
            maxbytes = video_type.filesize
            progress_bar[ "maximum" ] = maxbytes
            print( maxbytes )
            video_type.download( FILENAME )
        
        def restartorsth() :
            global again
            again = True
            root.destroy()
            pass
        
        # Starting the loop
        root = tk.Tk()
        BG_IMG = tk.PhotoImage( file = VIDDOWN_SINGLE_BGIMG )
        
        # Creating the Canvas
        canvas = tk.Canvas( root, height = HEIGHT, width = WIDTH )
        canvas.pack()
        
        # Placing the background image in the canvas
        BG_IMG_LABEL = tk.Label( canvas, image = BG_IMG )
        BG_IMG_LABEL.place( relwidth = 1, relheight = 1 )
        
        # scrapping the thumbnail from the current video and putting it in some folder
        General.get_video_tnl( url, tnurl )
        
        # displaying the thumbnail
        img = Image.open( os.path.join( 'Assets/Thumbnails', General.get_vid_id( url ) + '.png' ) )
        img = img.resize( (283, 160), Image.ANTIALIAS )
        img = ImageTk.PhotoImage( img )
        video_tnl = tk.Label( canvas, image = img )
        video_tnl.place( relx = 0.01, rely = 0.2 )
        
        # displaying the title of the video
        vid_title = tk.Label( canvas, text = title, anchor = 'w', font = ("Calibre", 18), bg = 'white', wraplength = 800 )
        vid_title.place( rely = 0.2, relx = 0.25 )
        
        # displaying the length of the video
        vid_len = General.conv_len( length )
        vid_length = tk.Label( canvas, text = vid_len, anchor = 'w', font = ("Calibre", 18), bg = 'white', wraplength = 400 )
        vid_length.place( rely = 0.38, relx = 0.25 )
        
        # Creating the drop down menu
        
        tkvar = tk.StringVar( root )
        list1 = [ '720p', '360p' ]
        tkvar.set( list1[ 0 ] )  # set the default option
        popupMenu = tk.OptionMenu( canvas, tkvar, *list1 )
        popupMenu.place( relx = 0.4, rely = 0.5, relwidth = 0.1, relheight = 0.05 )
        tkvar.trace( 'w', change_dropdown )
        
        download_img = tk.PhotoImage( file = 'C:/Users/littl/Desktop/Programs/Python/Kappa Video Downloader/download.png' )
        
        dimg = Image.open( 'C:/Users/littl/Desktop/Programs/Python/Kappa Video Downloader/download.png' )
        dimg = dimg.resize( (150, 150), Image.ANTIALIAS )
        dimg = ImageTk.PhotoImage( dimg )
        
        # Displaying the download button
        down_btn = tk.Button( canvas, text = "Downlaod", image = dimg, command = lambda : threading.Thread( target = download ).start(),
                              font = ("Calibre", 16), bg = 'white', border = 0, activebackground = 'white' )
        down_btn.place( rely = 0.6, relx = 0.8 )
        
        # displaying the file selection button
        file_selection_btn = tk.Button( canvas, text = "...", command = open_file_explorer, font = ("Calibre", 16) )
        file_selection_btn.place( rely = 0.7, relx = 0.7 )
        
        # displaying the file path text box
        file_path = tk.Label( canvas, text = FILENAME, font = ("Calibre", 18, 'italic'), bg = 'white', )
        file_path.place( rely = 0.7, relx = 0.05 )
        
        progress_bar = ttk.Progressbar( canvas, orient = "horizontal", length = 200, mode = "determinate" )
        progress_bar.place( rely = 0.85, relx = 0.05, relwidth = 0.7, relheight = 0.05 )
        progress_bar[ 'value' ] = 0
        
        # displaying the amount of video downlaoded
        progress_value = tk.Label( canvas, text = '', font = ("Calibre", 18), bg = 'white' )
        progress_value.place( rely = 0.9, relx = 0.30 )
        
        # displaying the button for downloading another video, that is restarting the program
        next_btn = tk.Button( canvas, text = "Downlaod Another Video!", command = restartorsth, font = ("Calibre", 16), bg = 'white' )
        next_btn.place( rely = 0.9, relx = 0.8 )
        root.mainloop()
    
    # this window shows you the thumbnail of each video in a scrollbar fashion(?) and then you download and there is checkbox
    @staticmethod
    def sel_downlaod_win_playlist() :
        pass

def main() :
    leave = False
    global again
    while again :
        # runs the intro function first to get the url
        again = False
        window.intro_win()
        if TYPE == 'SINGLE' :
            print( URL )
            yt = pt.YouTube( URL )
            window.sel_download_win_single( URL, yt.thumbnail_url, yt.title, yt.length, yt.author )
        else :
            window.sel_downlaod_win_playlist()
    if not again :
        print( 'Thanks for using Kappa video downloader' )

main()
